# %% [markdown]
# # AI 09c Sarsa
# ---
#
# > 학번:
# >
# > 이름:
#
#
# Source: https://github.com/wikibook/pytorch-drl

# %% [markdown]
# ### Import packages
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Sarsa
# ---

# %%
# 9c.2

# 초기 상태의 미로 모습

# 전체 그림의 크기 및 그림을 나타내는 변수 선언
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 붉은 벽 그리기
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 상태를 의미하는 문자열(S0~S8) 표시
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 그림을 그릴 범위 및 눈금 제거 설정
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom=False, top=False,
                labelbottom=False, right=False, left=False, labelleft=False)

# S0에 녹색 원으로 현재 위치를 표시
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)

# %%
# 9c.3

# 정책을 결정하는 파라미터의 초깃값 theta_0를 설정

# 줄은 상태 0~7, 열은 행동방향(상,우,하,좌 순)를 나타낸다
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8은 목표지점이므로 정책이 없다
                    ])

# %%
# 9c.4

# 파라미터 theta를 행동 정책 pi로 변환하는 함수
def theta_to_pi(theta):
    '''단순히 값의 비율을 계산'''

    [m, n] = theta.shape  # theta의 shape
    
    pi = np.zeros((m, n))
    
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 비율 계산

    pi = np.nan_to_num(pi)  # nan을 0으로 변환

    return pi

# 무작위 행동정책 pi_0을 계산
pi_0 = theta_to_pi(theta_0)

# %%
# 9c.5

# 행동가치 함수 Q의 초기 상태

[a, b] = theta_0.shape  # 열과 행의 갯수를 변수 a, b에 저장
Q = np.random.rand(a, b) * theta_0
# * theta0 로 요소 단위 곱셈을 수행, Q에서 벽 방향으로 이동하는 행동에는 nan을 부여

# %%
# 9c.6 Edit

# ε-greedy 알고리즘 구현

def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]

    # 행동을 결정
    # Edit this



    

    # 행동을 인덱스로 변환
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3

    return action

# %%
def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a]  # 행동 a의 방향

    # 행동으로 다음 상태를 결정
    if next_direction == "up":
        s_next = s - 3  # 위로 이동하면 상태값이 3 줄어든다
    elif next_direction == "right":
        s_next = s + 1  # 오른쪽으로 이동하면 상태값이 1 늘어난다
    elif next_direction == "down":
        s_next = s + 3  # 아래로 이동하면 상태값이 3 늘어난다
    elif next_direction == "left":
        s_next = s - 1  # 왼쪽으로 이동하면 상태값이 1 줄어든다

    return s_next

# %%
# 9c.7 Edit

# Sarsa 알고리즘으로 행동가치 함수 Q를 수정

def Sarsa(s, a, r, s_next, a_next, Q, eta, gamma):


    # Edit this


    return Q

# %%
# 9c.8 Edit

# Sarsa 알고리즘으로 미로를 빠져나오는 함수, 상태 및 행동 그리고 Q값의 히스토리를 출력한다

def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0  # 시작 지점
    a = a_next = get_action(s, Q, epsilon, pi)  # 첫 번째 행동
    s_a_history = [[0, np.nan]]  # 에이전트의 행동 및 상태의 히스토리를 기록하는 리스트

    while (1):  # 목표 지점에 이를 때까지 반복
        a = a_next  # 행동 결정

        s_a_history[-1][1] = a
        # 현재 상태(마지막이므로 인덱스가 -1)을 히스토리에 추가

        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 다음 단계의 상태를 구함

        s_a_history.append([s_next, np.nan])
        # 다음 상태를 히스토리에 추가, 행동은 아직 알 수 없으므로 nan으로 둔다

        # 보상을 부여하고 다음 행동을 계산함
        if s_next == 8:
            r = 1  # 목표 지점에 도달했다면 보상을 부여
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 다음 행동 a_next를 계산



        # 가치함수를 수정
        # Edit this



        # 종료 여부 판정
        if s_next == 8:  # 목표 지점에 도달하면 종료
            break
        else:
            s = s_next

    return [s_a_history, Q]

# %%
# 9c.9

# Sarsa 알고리즘으로 미로 빠져나오기

eta = 0.1  # 학습률
gamma = 0.9  # 시간할인율
epsilon = 0.5  # ε-greedy 알고리즘 epsilon 초깃값
v = np.nanmax(Q, axis=1)  # 각 상태마다 가치의 최댓값을 계산
is_continue = True
episode = 1

while is_continue:  # is_continue의 값이 False가 될 때까지 반복
    print("에피소드: " + str(episode))

    # ε 값을 조금씩 감소시킴
    epsilon = epsilon / 2

    # Sarsa 알고리즘으로 미로를 빠져나온 후, 결과로 나온 행동 히스토리와 Q값을 변수에 저장
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)

    # 상태가치의 변화
    new_v = np.nanmax(Q, axis=1)  # 각 상태마다 행동가치의 최댓값을 계산
    print(np.sum(np.abs(new_v - v)))  # 상태가치 함수의 변화를 출력
    v = new_v

    print("목표 지점까지 {} 단계".format(len(s_a_history) - 1) )

    # 100 에피소드 반복
    episode = episode + 1
    if episode > 100:
        break
# Out:
# 에피소드: 1
# 0.8081280374313168
# 목표 지점까지 52 단계
# 에피소드: 2
# 1.2508296361902105
# 목표 지점까지 394 단계
# 에피소드: 3
# 0.20991343307825255
# 목표 지점까지 42 단계
# 에피소드: 4
# 0.05692093408882326
# 목표 지점까지 14 단계
# 에피소드: 5
# 0.07359809206811413
# 목표 지점까지 10 단계
# 에피소드: 6
# 0.05675758171108658
# 목표 지점까지 4 단계
# 에피소드: 7
# 0.05583348223225909
# 목표 지점까지 4 단계
# 에피소드: 8
# 0.05495368787179161
# 목표 지점까지 4 단계
# 에피소드: 9
# 0.05411245428290001
# 목표 지점까지 4 단계
# 에피소드: 10
# 0.053301697190156594
# 목표 지점까지 4 단계
# 에피소드: 11
# 0.05251218821122833
# 목표 지점까지 4 단계
# 에피소드: 12
# 0.05173443129251554
# 목표 지점까지 4 단계
# 에피소드: 13
# 0.05095928569797176
# 목표 지점까지 4 단계
# 에피소드: 14
# 0.050178389728552986
# 목표 지점까지 4 단계
# 에피소드: 15
# 0.04938442949423649
# 목표 지점까지 4 단계
# 에피소드: 16
# 0.04857128882274997
# 목표 지점까지 4 단계
# 에피소드: 17
# 0.047734109521931634
# 목표 지점까지 4 단계
# 에피소드: 18
# 0.04686928550467939
# 목표 지점까지 4 단계
# 에피소드: 19
# 0.04597440955622806
# 목표 지점까지 4 단계
# 에피소드: 20
# 0.04504818761902585
# 목표 지점까지 4 단계
# 에피소드: 21
# 0.04409033225953024
# 목표 지점까지 4 단계
# 에피소드: 22
# 0.043101444352184104
# 목표 지점까지 4 단계
# 에피소드: 23
# 0.04208288987378417
# 목표 지점까지 4 단계
# 에피소드: 24
# 0.041036676965955476
# 목표 지점까지 4 단계
# 에피소드: 25
# 0.03996533702633953
# 목표 지점까지 4 단계
# 에피소드: 26
# 0.038871812472765555
# 목표 지점까지 4 단계
# 에피소드: 27
# 0.03775935294048227
# 목표 지점까지 4 단계
# 에피소드: 28
# 0.03663142097953803
# 목표 지점까지 4 단계
# 에피소드: 29
# 0.035491607783196266
# 목표 지점까지 4 단계
# 에피소드: 30
# 0.03434355907001663
# 목표 지점까지 4 단계
# 에피소드: 31
# 0.03319091093780824
# 목표 지점까지 4 단계
# 에피소드: 32
# 0.0320372352869544
# 목표 지점까지 4 단계
# 에피소드: 33
# 0.030885994256901195
# 목표 지점까지 4 단계
# 에피소드: 34
# 0.029740503019056785
# 목표 지점까지 4 단계
# 에피소드: 35
# 0.028603900210527777
# 목표 지점까지 4 단계
# 에피소드: 36
# 0.02747912526663715
# 목표 지점까지 4 단계
# 에피소드: 37
# 0.02636890190834512
# 목표 지점까지 4 단계
# 에피소드: 38
# 0.025275727057282205
# 목표 지점까지 4 단계
# 에피소드: 39
# 0.024201864481044888
# 목표 지점까지 4 단계
# 에피소드: 40
# 0.02314934251066425
# 목표 지점까지 4 단계
# 에피소드: 41
# 0.022119955217482334
# 목표 지점까지 4 단계
# 에피소드: 42
# 0.02111526648555251
# 목표 지점까지 4 단계
# 에피소드: 43
# 0.020136616466108204
# 목표 지점까지 4 단계
# 에피소드: 44
# 0.019185129951136082
# 목표 지점까지 4 단계
# 에피소드: 45
# 0.018261726252484678
# 목표 지점까지 4 단계
# 에피소드: 46
# 0.017367130220424576
# 목표 지점까지 4 단계
# 에피소드: 47
# 0.016501884080551532
# 목표 지점까지 4 단계
# 에피소드: 48
# 0.015666359810027508
# 목표 지점까지 4 단계
# 에피소드: 49
# 0.014860771813121176
# 목표 지점까지 4 단계
# 에피소드: 50
# 0.014085189691770417
# 목표 지점까지 4 단계
# 에피소드: 51
# 0.013339550939394651
# 목표 지점까지 4 단계
# 에피소드: 52
# 0.012623673415519066
# 목표 지점까지 4 단계
# 에피소드: 53
# 0.011937267485024217
# 목표 지점까지 4 단계
# 에피소드: 54
# 0.011279947729169182
# 목표 지점까지 4 단계
# 에피소드: 55
# 0.01065124415610752
# 목표 지점까지 4 단계
# 에피소드: 56
# 0.010050612856633778
# 목표 지점까지 4 단계
# 에피소드: 57
# 0.00947744606653178
# 목표 지점까지 4 단계
# 에피소드: 58
# 0.008931081610376035
# 목표 지점까지 4 단계
# 에피소드: 59
# 0.008410811713131183
# 목표 지점까지 4 단계
# 에피소드: 60
# 0.007915891175614087
# 목표 지점까지 4 단계
# 에피소드: 61
# 0.007445544917997982
# 목표 지점까지 4 단계
# 에피소드: 62
# 0.006998974902231114
# 목표 지점까지 4 단계
# 에피소드: 63
# 0.006575366449667275
# 목표 지점까지 4 단계
# 에피소드: 64
# 0.006173893974520617
# 목표 지점까지 4 단계
# 에피소드: 65
# 0.005793726157098611
# 목표 지점까지 4 단계
# 에피소드: 66
# 0.005434030583260863
# 목표 지점까지 4 단계
# 에피소드: 67
# 0.005093977878315337
# 목표 지점까지 4 단계
# 에피소드: 68
# 0.004772745364703845
# 목표 지점까지 4 단계
# 에피소드: 69
# 0.0044695202734374995
# 목표 지점까지 4 단계
# 에피소드: 70
# 0.004183502539404693
# 목표 지점까지 4 단계
# 에피소드: 71
# 0.00391390721046414
# 목표 지점까지 4 단계
# 에피소드: 72
# 0.0036599664997256642
# 목표 지점까지 4 단계
# 에피소드: 73
# 0.003420931509658609
# 목표 지점까지 4 단계
# 에피소드: 74
# 0.003196073655713949
# 목표 지점까지 4 단계
# 에피소드: 75
# 0.0029846858160441636
# 목표 지점까지 4 단계
# 에피소드: 76
# 0.0027860832326833673
# 목표 지점까지 4 단계
# 에피소드: 77
# 0.0025996041882609955
# 목표 지점까지 4 단계
# 에피소드: 78
# 0.0024246104809685365
# 목표 지점까지 4 단계
# 에피소드: 79
# 0.0022604877191367834
# 목표 지점까지 4 단계
# 에피소드: 80
# 0.0021066454553908542
# 목표 지점까지 4 단계
# 에피소드: 81
# 0.001962517178988432
# 목표 지점까지 4 단계
# 에피소드: 82
# 0.00182756018359842
# 목표 지점까지 4 단계
# 에피소드: 83
# 0.001701255326464035
# 목표 지점까지 4 단계
# 에피소드: 84
# 0.0015831066936311533
# 목표 지점까지 4 단계
# 에피소드: 85
# 0.001472641184695589
# 목표 지점까지 4 단계
# 에피소드: 86
# 0.001369408029366359
# 목표 지점까지 4 단계
# 에피소드: 87
# 0.0012729782470344286
# 목표 지점까지 4 단계
# 에피소드: 88
# 0.0011829440594838259
# 목표 지점까지 4 단계
# 에피소드: 89
# 0.0010989182659082442
# 목표 지점까지 4 단계
# 에피소드: 90
# 0.0010205335884633238
# 목표 지점까지 4 단계
# 에피소드: 91
# 0.0009474419957296032
# 목표 지점까지 4 단계
# 에피소드: 92
# 0.000879314010655774
# 목표 지점까지 4 단계
# 에피소드: 93
# 0.0008158380088114647
# 목표 지점까지 4 단계
# 에피소드: 94
# 0.0007567195120912196
# 목표 지점까지 4 단계
# 에피소드: 95
# 0.0007016804823785083
# 목표 지점까지 4 단계
# 에피소드: 96
# 0.0006504586191021788
# 목표 지점까지 4 단계
# 에피소드: 97
# 0.0006028066640855201
# 목표 지점까지 4 단계
# 에피소드: 98
# 0.0005584917166036041
# 목표 지점까지 4 단계
# 에피소드: 99
# 0.00051729456113081
# 목표 지점까지 4 단계
# 에피소드: 100
# 0.000479009009857867
# 목표 지점까지 4 단계

# %%
# 9c.12

# 에이전트의 이동 과정을 시각화
# 참고 URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML


def init():
    # 배경 이미지 초기화
    line.set_data([], [])
    return (line,)


def animate(i):
    # 프레임 단위로 이미지 생성
    state = s_a_history[i][0]  # 현재 위치
    x = (state % 3) + 0.5  # 상태의 x좌표 : 3으로 나눈 나머지 + 0.5
    y = 2.5 - int(state / 3)  # y좌표 : 2.5에서 3으로 나눈 몫을 뺌
    line.set_data(x, y)
    return (line,)


#　초기화 함수와 프레임 단위 이미지 생성한수를 사용하여 애니메이션 생성
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(
    s_a_history), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgb800bf01b988444398be91938a3509bb">
#   <div class="anim-controls">
#     <input id="_anim_sliderb800bf01b988444398be91938a3509bb" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animb800bf01b988444398be91938a3509bb.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animb800bf01b988444398be91938a3509bb.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animb800bf01b988444398be91938a3509bb.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animb800bf01b988444398be91938a3509bb.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animb800bf01b988444398be91938a3509bb.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animb800bf01b988444398be91938a3509bb.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animb800bf01b988444398be91938a3509bb.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animb800bf01b988444398be91938a3509bb.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animb800bf01b988444398be91938a3509bb.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animb800bf01b988444398be91938a3509bb.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectb800bf01b988444398be91938a3509bb" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_b800bf01b988444398be91938a3509bb"
#              checked>
#       <label for="_anim_radio1_b800bf01b988444398be91938a3509bb">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_b800bf01b988444398be91938a3509bb"
#              >
#       <label for="_anim_radio2_b800bf01b988444398be91938a3509bb">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_b800bf01b988444398be91938a3509bb"
#              >
#       <label for="_anim_radio3_b800bf01b988444398be91938a3509bb">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb800bf01b988444398be91938a3509bb";
#     var slider_id = "_anim_sliderb800bf01b988444398be91938a3509bb";
#     var loop_select_id = "_anim_loop_selectb800bf01b988444398be91938a3509bb";
#     var frames = new Array(5);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+j8jraAAAclElEQVR4nO3df1SUdd7/8dfADAgMLH7TDLDAbldZ\
# /OZaoAd0N1PslrbjtmW4B2pLab374VZ30rE669qvb3takzy2+W3z3EprtbX9NHW3VlKj9cfmQrp2\
# a275LVLRFmQ1RX4OfL5/jHgLKwIKXJ+ZeT7OmVMy1wxvPgeeXFxcXOMyxhgBAKwT5vQAAIAzI9AA\
# YCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkC\
# DQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCW\
# ItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAAYCkCDQCWItAA\
# YCkCDQCWItAAYCm30wOci0GDBik
