# %% [markdown]
# # AI 05
#
# > 학번: 2016145015
# >
# > 이름: 이두현
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 단순한 계층 구현
# ___

# %%
# 5.1 MultLayer

class MultLayer:
    def __init__(self):
        self.x = None
        self.y = None

    def forward(self, x, y):
        self.x = x
        self.y = y
        
        return x*y

    def backward(self, dout):
        dx = dout * self.y
        dy = dout * self.x

        return dx, dy

# %%
# 5.2
apple = 100
apple_num = 2
tax = 1.1

layer1 = MultLayer()
layer2 = MultLayer()

out1 = layer1.forward(apple, apple_num)
out2 = layer2.forward(out1, tax)

print('price =', out2 )
# Out:
# price = 220.00000000000003

# %%
# 5.3
dout2 = 1
dout1, dtax = layer2.backward(dout2)
dapple, dapple_num = layer1.backward(dout1)

print('dout1 =', dout1)
print('dtax =', dtax)
print('dapple =', dapple)
print('dapple_num =', dapple_num)
# Out:
# dout1 = 1.1
# dtax = 200
# dapple = 2.2
# dapple_num = 110.00000000000001

# %%
# 5.4 AddLayer

class AddLayer:
    def forward(self, x, y):
        return x+y

    def backward(self, dout):
        return dout, dout

# %%
# 5.5

apple = 100
apple_num = 2
orange = 150
orange_num = 3
tax = 1.1

layer1 = MultLayer()
layer2 = MultLayer()
layer3 = AddLayer()
layer4 = MultLayer()

# forward
sum_apple = layer1.forward(apple, apple_num)
sum_orange = layer2.forward(orange, orange_num)
sum_all = layer3.forward(sum_apple, sum_orange)
price = layer4.forward(sum_all, tax)

# backward
dprice = 1
dsum_all, dtax = layer4.backward(dprice)
dsum_apple, dsum_orange = layer3.backward(dsum_all)
dorange, dorange_num = layer2.backward(dsum_orange)
dapple, dapple_num = layer1.backward(dsum_apple)

print('price = {:.2f}'.format(price))
print('dapple = {:.2f}, dapple_num = {:.2f}, \
dorange = {:.2f}, dorange_num = {:.2f}, \
dtax = {:.2f}'.format(dapple, dapple_num, dorange, dorange_num, dtax))
# Out:
# price = 715.00
# dapple = 2.20, dapple_num = 110.00, dorange = 3.30, dorange_num = 165.00, dtax = 650.00

# %% [markdown]
# ### 활성화 함수 계층
# ___

# %%
# 5.6 ReLU

class ReLU:
    def __init__(self):
        self.mask = None

    def forward(self, x):
        self.mask = (x <= 0)
        out = x.copy()
        out[self.mask] = 0

        return out
    
    def backward(self, dout):
        dout[self.mask] = 0
        dx = dout

        return dx

# %%
# 5.7
x = np.array([[1.0, -0.5], [-2.0, 3.0]])
print(x)

mask = (x<=0)
print(mask)
# Out:
# [[ 1.  -0.5]
#  [-2.   3. ]]
# [[False  True]
#  [ True False]]

# %%
# 5.8 Sigmoid

class Sigmoid:
    def __init__(self):
        self.out = None

    def forward(self, x):
        out = 1 / (1 + np.exp(-x))
        self.out = out

        return out

    def backward(self, dout):
        dx = dout * (1.0 - self.out) * self.out

        return dx

# %% [markdown]
# ### Affine / Softmax 계층
# ___

# %%
# 5.9
X = np.random.rand(2)
W = np.random.rand(2, 3)
B = np.random.rand(3)

print( X.shape )
print( W.shape )
print( B.shape )


Y = np.dot(X, W) + B
print( Y )
# Out:
# (2,)
# (2, 3)
# (3,)
# [0.62570076 1.24570527 1.26446494]

# %%
# 5.10
X_dot_W = np.array([[0,0,0], [10,10,10]])
B = np.array([1,2,3])

print( X_dot_W )
print( X_dot_W + B )
# Out:
# [[ 0  0  0]
#  [10 10 10]]
# [[ 1  2  3]
#  [11 12 13]]

# %%
# 5.11
dY = np.array([[1,2,3], [4,5,6]])
print(dY)

dB = np.sum(dY, axis = 0)
print(dB)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [5 7 9]

# %%
# 5.12 Affine

class Affine:
    def __init__(self, W, b):
        self.W = W
        self.b = b
        self.x = None
        self.dW = None
        self.db = None
    
    def forward(self, x):
        self.x = x
        out = np.dot(x, self.W) + self.b
        
        return out
    
    def backward(self, dout):
        dx = np.dot(dout, self.W.T)
        self.dW = np.dot(self.x.T, dout)
        self.db = np.sum(dout, axis=0)
        
        return dx

# %%
# 5.13 SoftmaxWithLoss

class SoftmaxWithLoss:
    def __init__(self):
        self.loss = None
        self.o = None
        self.t = None
        
    def forward(self, x, t):
        self.t = t
        self.o = softmax(x)
        self.loss = ce_loss(self.o, self.t)
    
        return self.loss
    
    def backward(self, dout=1):
        batch_size = self.t.shape[0]
        dx = (self.o - self.t) / batch_size
        
        return dx

# %% [markdown]
# ### 오차역전파법
# ___

# %%
from sklearn.datasets import fetch_openml
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)

X = X.astype(np.float) / 255.
y = y.astype(np.uint8)

# one-hot encoding
y = np.eye(10)[y]

x_train = X[:60000]
x_test = X[60000:]
t_train = y[:60000]
t_test = y[60000:]

print(x_train.shape)
print(t_train.shape)
print(x_test.shape)
print(t_test.shape)
# Out:
# (60000, 784)
# (60000, 10)
# (10000, 784)
# (10000, 10)

# %%
def softmax(x):
    if x.ndim == 2:
        x = x.T
        x = x - np.max(x, axis=0)
        y = np.exp(x) / np.sum(np.exp(x), axis=0)
        return y.T 

    x = x - np.max(x)
    return np.exp(x) / np.sum(np.exp(x))

# %%
def ce_loss(o, t):
    if o.ndim == 1:
        t = t.reshape(1, t.size)
        o = o.reshape(1, o.size)
        
    if t.size == o.size:
        t = t.argmax(axis=1)
             
    batch_size = o.shape[0]
    return -np.sum(np.log(o[np.arange(batch_size), t] + 1e-7)) / batch_size

# %%
# 5.14 TwoLayerNet

class TwoLayerNet:
    def __init__(self, i_size, h_size, o_size, init_std = 0.01):
        self.params = {}
        self.params['W1'] = init_std * np.random.randn(i_size, h_size)
        self.params['b1'] = np.zeros(h_size)
        self.params['W2'] = init_std * np.random.randn(h_size, o_size) 
        self.params['b2'] = np.zeros(o_size)

        self.layers = {}
        self.layers['Affine1'] = Affine(self.params['W1'], self.params['b1'])
        self.layers['Relu1'] = ReLU()
        self.layers['Affine2'] = Affine(self.params['W2'], self.params['b2'])
        self.layers['SoftmaxWithLoss'] = SoftmaxWithLoss()
        
    def predict(self, x):
        for key in ('Affine1', 'Relu1', 'Affine2'):
            x = self.layers[key].forward(x)
        
        return x
        
    def loss(self, x, t):
        o = self.predict(x)
        return self.layers['SoftmaxWithLoss'].forward(o, t)
    
    def accuracy(self, x, t):
        o = self.predict(x)
        o = np.argmax(o, axis=1)
        if t.ndim != 1: 
            t = np.argmax(t, axis=1)
        
        accuracy = np.sum(o == t) / float(x.shape[0])
        return accuracy
        
    def gradient(self, x, t):
        
        # forward
        self.loss(x, t)

        # backward
        dout = 1
        for key in ('SoftmaxWithLoss', 'Affine2', 'Relu1', 'Affine1'):
            dout = self.layers[key].backward(dout)

        grads = {}
        grads['W1'] = self.layers['Affine1'].dW
        grads['b1'] = self.layers['Affine1'].db
        grads['W2'] = self.layers['Affine2'].dW
        grads['b2'] = self.layers['Affine2'].db
        
        return grads

# %%
# 5.16

network = TwoLayerNet(i_size=784, h_size=100, o_size=10)

train_size = x_train.shape[0]
batch_size = 100

learning_rate = 0.1

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size // batch_size, 1)
epoch_num = 50
iters_num = epoch_num * iter_per_epoch

epoch = 0

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    grad = network.gradient(x_batch, t_batch)

    for key in network.params.keys():
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, t_batch)
    train_loss_list.append(loss)
    
    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)
        
        epoch += 1
        print( 'epoch {} accuracy: train {:.4f}, test {:.4f}'.format(
            epoch, train_acc, test_acc) )
# Out:
# epoch 1 accuracy: train 0.1389, test 0.1383
# epoch 2 accuracy: train 0.9071, test 0.9089
# epoch 3 accuracy: train 0.9304, test 0.9333
# epoch 4 accuracy: train 0.9382, test 0.9369
# epoch 5 accuracy: train 0.9497, test 0.9491
# epoch 6 accuracy: train 0.9543, test 0.9513
# epoch 7 accuracy: train 0.9611, test 0.9586
# epoch 8 accuracy: train 0.9654, test 0.9612
# epoch 9 accuracy: train 0.9684, test 0.9645
# epoch 10 accuracy: train 0.9689, test 0.9640
# epoch 11 accuracy: train 0.9736, test 0.9679
# epoch 12 accuracy: train 0.9753, test 0.9685
# epoch 13 accuracy: train 0.9780, test 0.9715
# epoch 14 accuracy: train 0.9786, test 0.9716
# epoch 15 accuracy: train 0.9806, test 0.9719
# epoch 16 accuracy: train 0.9817, test 0.9722
# epoch 17 accuracy: train 0.9834, test 0.9750
# epoch 18 accuracy: train 0.9843, test 0.9748
# epoch 19 accuracy: train 0.9856, test 0.9733
# epoch 20 accuracy: train 0.9863, test 0.9749
# epoch 21 accuracy: train 0.9875, test 0.9756
# epoch 22 accuracy: train 0.9882, test 0.9751
# epoch 23 accuracy: train 0.9887, test 0.9763
# epoch 24 accuracy: train 0.9893, test 0.9765
# epoch 25 accuracy: train 0.9897, test 0.9767
# epoch 26 accuracy: train 0.9905, test 0.9759
# epoch 27 accuracy: train 0.9903, test 0.9768
# epoch 28 accuracy: train 0.9919, test 0.9764
# epoch 29 accuracy: train 0.9917, test 0.9764
# epoch 30 accuracy: train 0.9924, test 0.9768
# epoch 31 accuracy: train 0.9927, test 0.9758
# epoch 32 accuracy: train 0.9932, test 0.9770
# epoch 33 accuracy: train 0.9937, test 0.9772
# epoch 34 accuracy: train 0.9939, test 0.9761
# epoch 35 accuracy: train 0.9947, test 0.9763
# epoch 36 accuracy: train 0.9950, test 0.9773
# epoch 37 accuracy: train 0.9951, test 0.9776
# epoch 38 accuracy: train 0.9956, test 0.9768
# epoch 39 accuracy: train 0.9955, test 0.9775
# epoch 40 accuracy: train 0.9958, test 0.9769
# epoch 41 accuracy: train 0.9962, test 0.9773
# epoch 42 accuracy: train 0.9965, test 0.9771
# epoch 43 accuracy: train 0.9960, test 0.9780
# epoch 44 accuracy: train 0.9970, test 0.9782
# epoch 45 accuracy: train 0.9971, test 0.9777
# epoch 46 accuracy: train 0.9971, test 0.9774
# epoch 47 accuracy: train 0.9977, test 0.9781
# epoch 48 accuracy: train 0.9978, test 0.9774
# epoch 49 accuracy: train 0.9979, test 0.9771
# epoch 50 accuracy: train 0.9981, test 0.9783

# %%
# 5.17

plt.plot(train_loss_list)
plt.show()

# %%
# 5.18

plt.plot(train_acc_list, label='train')
plt.plot(test_acc_list, label='test')
plt.legend()
plt.show()

# %% [markdown]
# ### ThreeLayerNet
# ---

# %%
# 5.19 ThreeLayerNet

class ThreeLayerNet:

    def __init__(self, i_size, h1_size, h2_size, o_size, init_std = 0.01):

        self.params = {}
        self.params['W1'] = init_std * np.random.randn(i_size, h1_size)
        self.params['b1'] = np.zeros(h1_size)
        self.params['W2'] = init_std * np.random.randn(h1_size, h2_size) 
        self.params['b2'] = np.zeros(h2_size)
        self.params['W3'] = init_std * np.random.randn(h2_size, o_size) 
        self.params['b3'] = np.zeros(o_size)

        self.layers = {}
        self.layers['Affine1'] = Affine(self.params['W1'], self.params['b1'])
        self.layers['Relu1'] = ReLU()
        self.layers['Affine2'] = Affine(self.params['W2'], self.params['b2'])
        self.layers['Relu2'] = ReLU()
        self.layers['Affine3'] = Affine(self.params['W3'], self.params['b3'])
        self.layers['SoftmaxWithLoss'] = SoftmaxWithLoss()


    def predict(self, x): 
        for key in ('Affine1', 'Relu1', 'Affine2', 'Relu2', 'Affine3'): # #Edit
            x = self.layers[key].forward(x)
        
        return x
        
    def loss(self, x, t):
        o = self.predict(x)
        return self.layers['SoftmaxWithLoss'].forward(o, t)
    
    def accuracy(self, x, t):
        o = self.predict(x)
        o = np.argmax(o, axis=1)
        if t.ndim != 1 : t = np.argmax(t, axis=1)
        
        accuracy = np.sum(o == t) / float(x.shape[0])
        return accuracy
        
    def gradient(self, x, t):
        
        # forward
        self.loss(x, t)

        # backward
        dout = 1
        for key in ( 'SoftmaxWithLoss', 'Affine3', 'Relu2', 'Affine2', 'Relu1', 'Affine1'): # Edit
            dout = self.layers[key].backward(dout)

        grads = {}
        grads['W1'] = self.layers['Affine1'].dW
        grads['b1'] = self.layers['Affine1'].db
        grads['W2'] = self.layers['Affine2'].dW
        grads['b2'] = self.layers['Affine2'].db
        grads['W3'] = self.layers['Affine3'].dW
        grads['b3'] = self.layers['Affine3'].db
        
        return grads

# %%
# 5.20

network = ThreeLayerNet(i_size=784, h1_size=300, h2_size=50, o_size=10)

train_size = x_train.shape[0]
batch_size = 100

learning_rate = 0.1

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size // batch_size, 1)
epoch_num = 50
iters_num = epoch_num * iter_per_epoch

epoch = 0

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    grad = network.gradient(x_batch, t_batch)
    
    for key in network.params.keys():
        network.params[key] -= learning_rate * grad[key]
    
    loss = network.loss(x_batch, t_batch)
    train_loss_list.append(loss)
    
    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)
        
        epoch += 1
        print( 'epoch {} accuracy: train {:.4f}, test {:.4f}'.format(epoch, train_acc, test_acc) )
# Out:
# epoch 1 accuracy: train 0.1044, test 0.1028
# epoch 2 accuracy: train 0.8214, test 0.8309
# epoch 3 accuracy: train 0.9059, test 0.9049
# epoch 4 accuracy: train 0.9456, test 0.9425
# epoch 5 accuracy: train 0.9592, test 0.9562
# epoch 6 accuracy: train 0.9687, test 0.9635
# epoch 7 accuracy: train 0.9737, test 0.9681
# epoch 8 accuracy: train 0.9787, test 0.9713
# epoch 9 accuracy: train 0.9795, test 0.9724
# epoch 10 accuracy: train 0.9843, test 0.9726
# epoch 11 accuracy: train 0.9844, test 0.9738
# epoch 12 accuracy: train 0.9873, test 0.9735
# epoch 13 accuracy: train 0.9886, test 0.9754
# epoch 14 accuracy: train 0.9908, test 0.9766
# epoch 15 accuracy: train 0.9906, test 0.9772
# epoch 16 accuracy: train 0.9934, test 0.9782
# epoch 17 accuracy: train 0.9930, test 0.9764
# epoch 18 accuracy: train 0.9952, test 0.9789
# epoch 19 accuracy: train 0.9952, test 0.9776
# epoch 20 accuracy: train 0.9966, test 0.9799
# epoch 21 accuracy: train 0.9978, test 0.9796
# epoch 22 accuracy: train 0.9980, test 0.9786
# epoch 23 accuracy: train 0.9979, test 0.9785
# epoch 24 accuracy: train 0.9987, test 0.9799
# epoch 25 accuracy: train 0.9989, test 0.9785
# epoch 26 accuracy: train 0.9990, test 0.9798
# epoch 27 accuracy: train 0.9992, test 0.9788
# epoch 28 accuracy: train 0.9994, test 0.9784
# epoch 29 accuracy: train 0.9996, test 0.9801
# epoch 30 accuracy: train 0.9997, test 0.9792
# epoch 31 accuracy: train 0.9998, test 0.9808
# epoch 32 accuracy: train 0.9998, test 0.9798
# epoch 33 accuracy: train 0.9998, test 0.9795
# epoch 34 accuracy: train 0.9998, test 0.9800
# epoch 35 accuracy: train 0.9999, test 0.9796
# epoch 36 accuracy: train 0.9999, test 0.9800
# epoch 37 accuracy: train 0.9999, test 0.9799
# epoch 38 accuracy: train 0.9999, test 0.9799
# epoch 39 accuracy: train 1.0000, test 0.9807
# epoch 40 accuracy: train 1.0000, test 0.9806
# epoch 41 accuracy: train 1.0000, test 0.9804
# epoch 42 accuracy: train 1.0000, test 0.9806
# epoch 43 accuracy: train 1.0000, test 0.9805
# epoch 44 accuracy: train 1.0000, test 0.9799
# epoch 45 accuracy: train 1.0000, test 0.9809
# epoch 46 accuracy: train 1.0000, test 0.9806
# epoch 47 accuracy: train 1.0000, test 0.9804
# epoch 48 accuracy: train 1.0000, test 0.9811
# epoch 49 accuracy: train 1.0000, test 0.9806
# epoch 50 accuracy: train 1.0000, test 0.9804

# %% [markdown]
# ### Test
# ---

# %%
plt.plot(train_loss_list)
plt.show()
plt.plot(train_acc_list, label='train')
plt.plot(test_acc_list, label='test')
plt.legend()
plt.show()

# %%
# 5.21

o_test = network.predict(x_test)

# %%
# 5.22

o1_test = np.argmax(o_test, axis=1)
t1_test = np.argmax(t_test, axis=1)

fail_mask = o1_test != t1_test

fail_images = x_test[ fail_mask ]
fail_predicts = o1_test[ fail_mask ]
fail_labels = t1_test[ fail_mask ]

# %%
# 5.23

fig = plt.figure(figsize=(16, 40))

image_num = fail_images.shape[0]
print('Failed images #', image_num)

for i in range(image_num):
    ax = fig.add_subplot( (image_num // 10) + 1, 10, i+1 )
    ax.set_title( '{} (label {})'.format(fail_predicts[i], fail_labels[i]) )
    ax.set_xticks([])
    ax.set_yticks([])
    ax.imshow( fail_images[i].reshape(28, 28), cmap='gray' )
plt.show()
# Out:
# Failed images # 195
